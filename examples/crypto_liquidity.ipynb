# %% [markdown]
# # Cryptocurrency Liquidity API

# %% [markdown]
# This notebook is used to acquire the top decentralized exchange along with the $USD amount of liquidity for a list of cryptocurrency tokens using the [tokendao Python client](https://github.com/Token-DAO/tokendao).

# %%
import requests
r = requests.get('https://raw.githubusercontent.com/Token-DAO/tokendao/main/tokendao/liquidity.py')
with open('liquidity.py', 'w') as f:
  f.write(r.text)
import liquidity as liq

# %% [markdown]
# Input list of token contract addresses. You can search for Ethereum tokens contract addresses on https://www.etherscan.io and Polygon tokens contract addresses on https://polygonscan.com/. Several have been pre-loaded below.

# %% [markdown]
# ### Comment and uncomment these token addresses as needed.

# %%
# Ethereum Token Contract Addresses
ethereum_addresses = [
                      "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2", # WETH
                      "0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599", # WBTC
                      "0x1cF4592ebfFd730c7dc92c1bdFFDfc3B9EfCf29a", # WAVES
                      "0xd2877702675e6cEb975b4A1dFf9fb7BAF4C91ea9", # WLUNA
                      "0x4E15361FD6b4BB609Fa63C81A2be19d873717870", # FTM
                      "0x3155BA85D5F96b2d030a4966AF206230e46849cb", # RUNE
                      "0xAa6E8127831c9DE45ae56bB1b0d4D4Da6e5665BD", # ETH2x-FLI
                      "0x0B498ff89709d3838a063f1dFA463091F9801c2b", # BTC2x-FLI
                      "0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0", # MATIC
                      ]

# %%
# Polygon Token Contract Addresses
polygon_addresses = [
                    "0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619", # WETH
                    "0x1BFD67037B42Cf73acF2047067bd4F2C47D9BfD6", # WBTC
                    "0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0", # MATIC
                    "0x2C89bbc92BD86F8075d1DEcc58C7F4E0107f286b", # AVAX
                    "0xf287D97B6345bad3D88856b26Fb7c0ab3F2C7976", # MATIC2x-FLI-P
                    "0x3Ad707dA309f3845cd602059901E39C4dcd66473", # ETH2x-FLI-P
                    "0xd6cA869a4EC9eD2C7E618062Cdc45306d8dBBc14", # BTC2x-FLI-P
                    "0xd93f7E271cB87c23AaA73edC008A79646d1F9912" # Wrapped SOL (Wormhole)
                    ]

# %%
stablecoin_addresses = [
                        "0xdac17f958d2ee523a2206206994597c13d831ec7", # USDT
                        "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48", # USDC
                        "0x6b175474e89094c44da98b954eedeac495271d0f", # DAI
                        "0x853d955acef822db058eb8505911ed77f175b99e", # FRAX
                        "0x8e870d67f660d95d5be530380d0ec0bd388289e1", # USDP
                        "0x674C6Ad92Fd080e4004b2312b45f796a192D27a0", # USDN
                        "0x5f98805A4E8be255a32880FDeC7F6728C6568bA0", # LUSD
                        "0x056Fd409E1d7A124BD7017459dFEa2F387b6d5Cd", # GUSD

                        "0x39AA39c021dfbaE8faC545936693aC917d5E7563", # cUSDC
                        "0x5d3a536E4D6DbD6114cc1Ead35777bAB948E3643", # cDAI
                        ]

# %% [markdown]
# The server status should be 200 for each server request. If you see anything but 200, you received a server error for that server request. You may have entered an invalid token address. See https://en.wikipedia.org/wiki/List_of_HTTP_status_codes for server codes.

# %%
ethereum_responses = liq.api_response(ethereum_addresses)
polygon_responses = liq.api_response(polygon_addresses)
stablecoin_responses = liq.api_response(stablecoin_addresses)
# Out:
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK
# Server Status: 200 OK

# %% [markdown]
# The application produces the following tables for Ethereum and Polygon blockchain token addresses.

# %%
# Ethereum tokens
liq.compile_liquidity(ethereum_addresses, ethereum_responses)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 151.17it/s]
#            Top DEX     Liquidity
# Symbol
# WETH       uniswap  $744,406,431
# WBTC       uniswap  $427,497,817
# MATIC      uniswap    $6,942,223
# ETH2x-FLI  uniswap    $4,840,969
# BTC2x-FLI  uniswap    $1,916,058
# FTM        uniswap    $1,099,393
# RUNE       uniswap      $327,532
# LUNA       uniswap      $108,299
# WAVES      uniswap        $3,239

# %%
# Polygon tokens
liq.compile_liquidity(polygon_addresses, polygon_responses)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 173.94it/s]
#                  Top DEX    Liquidity
# Symbol
# WETH           quickswap  $66,797,226
# WBTC           quickswap  $43,452,542
# MATIC            uniswap   $6,942,223
# SOL            quickswap     $816,399
# ETH2x-FLI-P    sushiswap     $357,312
# AVAX            balancer     $306,374
# MATIC2x-FLI-P    uniswap      $38,999
# BTC2x-FLI-P     balancer       $4,612

# %%
# Ethereum stablecoin tokens
liq.compile_liquidity(stablecoin_addresses, stablecoin_responses)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 239.01it/s]
# This address is invalid or has no liquidity: 0xdac17f958d2ee523a2206206994597c13d831ec7
# This address is invalid or has no liquidity: 0x39AA39c021dfbaE8faC545936693aC917d5E7563
#         Top DEX       Liquidity
# Symbol
# DAI     uniswap  $1,237,346,751
# FRAX    uniswap    $184,047,798
# USDC    uniswap    $158,842,762
# USDP    uniswap     $27,060,936
# LUSD    uniswap      $8,577,649
# GUSD    uniswap      $2,197,556
# cDAI    uniswap        $246,571
# USDN    uniswap        $105,375
