# %% [markdown]
# # Cryptocurrency Liquidity API

# %% [markdown]
# This notebook is used to acquire the top decentralized exchange along with the $USD amount of liquidity for a list of cryptocurrency tokens.

# %%
import requests
r = requests.get('https://raw.githubusercontent.com/Token-DAO/tokendao/main/src/tokendao/liquidity.py')
with open('liquidity.py', 'w') as f:
  f.write(r.text)
import liquidity as liq

# %% [markdown]
# Input list of token addresses. You can search Ethereum tokens on https://www.etherscan.io and Polygon tokens on https://polygonscan.com/. Several have been pre-loaded below.

# %%
# Ethereum Token Addresses
ethereum_addresses = [
                   "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2", # WETH
                   "0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599", # WBTC
                   "0x1cF4592ebfFd730c7dc92c1bdFFDfc3B9EfCf29a", # WAVES
                   "0xd2877702675e6cEb975b4A1dFf9fb7BAF4C91ea9", # WLUNA
                   "0x4E15361FD6b4BB609Fa63C81A2be19d873717870", # FTM
                   "0x3155BA85D5F96b2d030a4966AF206230e46849cb", # RUNE
                   "0xAa6E8127831c9DE45ae56bB1b0d4D4Da6e5665BD", # ETH2x-FLI
                   "0x0B498ff89709d3838a063f1dFA463091F9801c2b", # BTC2x-FLI
                   "0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0", # MATIC
                   ]

# %%
# Polygon Token Addresses
polygon_addresses = [
                   "0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619", # WETH
                   "0x1BFD67037B42Cf73acF2047067bd4F2C47D9BfD6", # WBTC
                   "0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0", # MATIC
                   "0x2C89bbc92BD86F8075d1DEcc58C7F4E0107f286b", # AVAX
                   "0xf287D97B6345bad3D88856b26Fb7c0ab3F2C7976", # MATIC2x-FLI-P
                   "0x3Ad707dA309f3845cd602059901E39C4dcd66473", # ETH2x-FLI-P
                   "0xd6cA869a4EC9eD2C7E618062Cdc45306d8dBBc14", # BTC2x-FLI-P
                   ]

# %% [markdown]
# The server status should be 200 for each server request. If you see anything but 200, you received a server error for that server request. You may have entered an invalid token address. See https://en.wikipedia.org/wiki/List_of_HTTP_status_codes for server codes.

# %%
ethereum_responses = liq.api_response(ethereum_addresses)
polygon_responses = liq.api_response(polygon_addresses)
# Out:
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200
# Status: 200

# %% [markdown]
# Running the above function produces the following tables for Ethereum and Polygon blockchain token addresses.

# %%
# Ethereum tokens
liq.compile_liquidity(ethereum_addresses, ethereum_responses)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 181.87it/s]
#            Top DEX     Liquidity
# Symbol
# WETH       uniswap  $749,041,420
# WBTC       uniswap  $501,735,752
# MATIC      uniswap    $7,697,247
# ETH2x-FLI  uniswap    $7,598,312
# BTC2x-FLI  uniswap    $2,137,321
# FTM        uniswap    $1,326,090
# RUNE       uniswap      $390,687
# LUNA       uniswap       $64,609
# WAVES      uniswap        $3,192

# %%
# Polygon tokens
liq.compile_liquidity(polygon_addresses, polygon_responses)
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 151.57it/s]
#                  Top DEX    Liquidity
# Symbol
# WETH           quickswap  $73,864,831
# WBTC           quickswap  $47,893,750
# MATIC            uniswap   $7,697,247
# ETH2x-FLI-P    sushiswap     $462,269
# AVAX            balancer     $389,360
# MATIC2x-FLI-P    uniswap      $45,316
# BTC2x-FLI-P     balancer       $5,265
